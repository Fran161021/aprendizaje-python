# %% [markdown]
# <a href="https://colab.research.google.com/github/Fran161021/aprendizaje-python/blob/main/03_operadores_logicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad = 22

# %%
print(edad >18 and edad < 30) # and = y. Evalua los dos si uno es false, todo sera falso
# Out:
# True

# %%
print(edad > 18 or edad < 30) # or = o pregunta si es mayor o menor que
# Out:
# True

# %%
print(not ( edad > 18)) # not = estoy negandolo por lo que será false, valor opuesto si pusiera < seria true.
# Out:
# False
