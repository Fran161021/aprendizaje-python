# %% [markdown]
# <a href="https://colab.research.google.com/github/Fran161021/aprendizaje-python/blob/main/MANIPULAR_CADENAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = "Francisco Javier"

# %%
primer_nombre = nombre[:5]
print(primer_nombre)
# Out:
# Franc

# %%
apellido = nombre[9:]
print(apellido)
# Out:
#  Javier

# %%
nombre_dos = nombre[-2]
print(nombre_dos)
# Out:
# e

# %%
website = "http//www.google.com"

# %%
slice = slice(11,-4)
print(website[slice])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2711/2094716380.py in <cell line: 0>()
# ----> 1 slice = slice(11,-4)
#       2 print(website[slice])
#
# TypeError: 'slice' object is not callable
