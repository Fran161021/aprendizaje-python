# %% [markdown]
# <a href="https://colab.research.google.com/github/Fran161021/aprendizaje-python/blob/main/01_fundamentos_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# VARIABLES

# %%
texto = "Mi nombre es Fran"

# %%
numero = 16 # int
decimal = 14.5 # float
verdadero = True # Boolean
falso = False # Boolean

# %% [markdown]
# STRINGS/METODOS

# %%
texto = "Mi nombre es Fran"
# Métodos de Strimgs
print(texto.upper())
print(texto.lower())
print(texto.find("Fran"))
nuevoNombre = texto.replace("Fran", "Francisco")
print(texto,nuevoNombre)
print("Fran" in texto") # Fran in texto devuelve True
# Out:
# MI NOMBRE ES FRAN

# %% [markdown]
# ARITMETICAS

# %%
print(5 + 15)
print(15 - 5)
print(5 * 15)
print(15 / 5)
print(5 ** 3)
print(10 % 3) # Esto es el módulo, es lo que resta de la divisón entre dos números, en este caso 1 porque 3,3,3 son 9, cuanto me queda para llegar a 10? 1.
