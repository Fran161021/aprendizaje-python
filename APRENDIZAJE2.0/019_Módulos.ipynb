# %% [markdown]
# <a href="https://colab.research.google.com/github/Fran161021/aprendizaje-python/blob/main/APRENDIZAJE2.0/019_M%C3%B3dulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Módulos: Un módulo es un archivo separado de python con extensión (.py) que tiene funciones o clases guardadas para poder usarlas en otros programas sin tener que volver a escribirlas. Aquí usaremos el from,import,as
# from: de
# import: importar
# as: como

# %% [markdown]
# El uso de estos 3 elementos.
# Usamos import a secas si vamos a necesitar usar muchas funciones diferentes de ese archivo
# usamos from ... import ... solo cuando vamos a uar una o dos funciones sueltas asi el programa va más rápido y más limpio
# usamos el as combinado con cualquiera de los otros es más que nada por si el nombre original es u¡mu largo y lo podemos abreviar

# %%
import  herramientas
mis_ips = [10,99,192]
herramientas.escanear_ips(mis_ips)
# Out:
# Acceso permitido
# IP Bloqueada
# Acceso permitido

# %% [markdown]
# en la 3 linea si te das cuenta pones el nombre del archivo del que vas a coger los datos el método de conexión que es el . y entre paréntesis el dato que le vas a pasar que es la lista que has creado en este nuevo archivo

# %% [markdown]
# Ahora vamos a ver un ejercicio para el segundo camino que es from ... import ...

# %%
from herramientas import escanear_ips
mis_ips = [10,99,192]
herramientas.escanear_ips(mis_ips)
# Out:
# Acceso permitido
# IP Bloqueada
# Acceso permitido

# %% [markdown]
# Imagina que tienes 6 funciones tú puedes coger las funciones que quieras o imagina que de esas 6 funciones quieres coger la 4 función solamente, pues le pasas el nombre de esa función solamente.
#
# Imagina que de esas 6 funciones quieres traerte dos funciones o 3 pues le metes el from "de" nombre de archivo y después de poner import le pasas el nombre de una función y luego el de la otra separada por , (una coma)
