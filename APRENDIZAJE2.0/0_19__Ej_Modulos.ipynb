# %% [markdown]
# <a href="https://colab.research.google.com/github/Fran161021/aprendizaje-python/blob/main/APRENDIZAJE2.0/0_19__Ej_Modulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from gaming import comprobar_usuarios
mis_usuarios = 120
comprobar_usuarios(mis_usuarios)
# Out:
# [CRÍTICO]: Servidor Colapsado

# %%
import gaming
mis_usuarios = 120
gaming.comprobar_usuarios(mis_usuarios)
# Out:
# [CRÍTICO]: Servidor Colapsado

# %%
import firewall
ip_entrante = 99
firewall.escanear_ip(ip_entrante)
# Out:
# [ALERTA] IP de Hacker bloqueado

# %%
from redes import filtrar_tráfico
lista_nodos = [800,620,400,200,160,490]
for nodos in lista_nodos:
  filtrar_tráfico(nodos)
# Out:
# [ALERTA] Tráfico excesivo
# [ALERTA] Tráfico excesivo
# Tráfico normal
# Tráfico normal
# Tráfico normal
# Tráfico normal

# %%
from tokens import validar_token
mis_tokens = ["AWS-999", "123", "TOKEN-PRO", "ab"]
for tokens in mis_tokens:
  validar_token(tokens)
# Out:
# Token válido y seguro
# Token demasiado corto
# Token válido y seguro
# Token demasiado corto

# %%
from balanceador import calcular_trafico
calcular_trafico(100,5)
calcular_trafico(100,0)
# Out:
# Reparto OK: Cada servidor recibe 20.0 GB
# [ALERTA RED]: Operación abortada. Motivo division by zero
