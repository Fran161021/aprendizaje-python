# %% [markdown]
# <a href="https://colab.research.google.com/github/Fran161021/aprendizaje-python/blob/main/APRENDIZAJE2.0/Condicionales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para que una ejecución se ejecute siempre tiene que ser True si es false no se va a ejecutar

# %%
mi_condicion = False
if mi_condicion == True:
  print("La condicion se cumple")

print("Ka ejecución continúa")

mi_condicion = 5 * 2
if mi_condicion == 11: # Aquí si estamos delimitando un valor le estamos obligando a que compruebe algo en concreto
  print("Se ejecuta la condición del segundo if")

print("La ejeución continúa")

mi_condicion = 5 * 2
if mi_condicion == 10: # Aquí como la condición es correcta pues se ejecutarán los dos prints
  print("Se ejecuta la condición del segundo if")

print("Ka ejecución continúa")
# Out:
# Ka ejecución continúa
# La ejeución continúa
# Se ejecuta la condición del segundo if
# Ka ejecución continúa

# %%
mi_nueva_condicion = 16
if mi_nueva_condicion >= 16:
  print("La condición se cumple")
else:
  print("La condición no se cumple")

otra_condicion = 6 * 5
if otra_condicion >= 30 and  otra_condicion < 20:
  print("La condición es mayor o igual que 30 y menor que 20")
else:
  print("La condición no se cumple")
# Out:
# La condición se cumple
# La condición no se cumple

# %%
mi_numero = 8
if mi_numero == 8:
  print("Tú numero es 8")
else:
  print("Tú número no es 8")
# Out:
# Tú numero es 8

# %%
una_prueba = 6 * 5
if una_prueba >= 30 and una_prueba < 25:
  print("La prueba es mayor o igual que 30 y menor que 25")
elif una_prueba == 30:
  print(" La prueba es igual a 30")
else:
  print("La prueba es menor que 30 o mayor que 30")

  una_prueba = 6 * 5
if una_prueba >= 30 and una_prueba <= 30:
  print("La prueba es mayor o igual que 30 y menor p igual que 30")
elif una_prueba == 30:
  print(" La prueba es igual a 30")
else:
  print("La prueba es menor que 30 o mayor que 30")
# un ejemplo para cuando funciona con elif y con el if normal con el else sale en los ejemplos de arriba
# Out:
#  La prueba es igual a 30
# La prueba es mayor o igual que 30 y menor p igual que 30
